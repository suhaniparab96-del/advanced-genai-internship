# %% [markdown]
# ### Problem Statement 1: Employee Performance Bonus Eligibility

# %%
# Dictionary of employee performance scores
employees = {
"Ravi": 92,
"Anita": 88,
"Kiran": 92,
"Suresh": 85
}


highest_score = max(employees.values())
highest_score
# Out:
# 92

# %%
#Employee name whose score highest score
top_performance =[name for name , score in employees.items() if score==highest_score]
top_performance
# Out:
# ['Ravi', 'Kiran']

# %%
print(f"Top Performers Eligible for Bonus: {','.join(top_performers)} (Score: {highest_score})")
# Out:
# Top Performers Eligible for Bonus: Ravi,Kiran (Score: 92)

# %% [markdown]
# ### Problem Statement 2: Search Query Keyword Analysis

# %%
import string
query = "Buy mobile phone buy phone online"

# Convert the input to lowercase.
query = query.lower()
query
# Out:
# 'buy mobile phone buy phone online'

# %%
query = query.translate(str.maketrans('', '', string.punctuation))
query
# Out:
# 'buy mobile phone buy phone online'

# %%
# Ignore common punctuation.
words = query.split()
words
# Out:
# ['buy', 'mobile', 'phone', 'buy', 'phone', 'online']

# %%
# Count the frequency of each keyword.
frequency = {}

for word in words:
    frequency[word] = frequency.get(word, 0) + 1

frequency
# Out:
# {'buy': 2, 'mobile': 1, 'phone': 2, 'online': 1}

# %%
# Display only keywords searched more than once.

result = {word: count for word, count in frequency.items() if count > 1}

print(result)
# Out:
# {'buy': 2, 'phone': 2}

# %% [markdown]
# ### Problem Statement 3: Sensor Data Validation

# %%
sensor_readings = [3, 4, 7, 8, 10, 12, 5]

valid_readings = []

for i in range(len(sensor_readings)):
    if sensor_readings[i] % 2 == 0:   # Check even number
        valid_readings.append((i, sensor_readings[i]))

print(valid_readings)
# Out:
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %% [markdown]
# ### Problem Statement 4: Email Domain Usage Analysis

# %%
emails = [
    "ravi@gmail.com",
    "anita@yahoo.com",
    "kiran@gmail.com",
    "suresh@gmail.com",
    "meena@yahoo.com"
]

gmail = 0
yahoo = 0

for email in emails:
    if "gmail.com" in email:
        gmail = gmail + 1
    elif "yahoo.com" in email:
        yahoo = yahoo + 1

print(gmail)
# Out:
# 3

# %%
print(yahoo)
# Out:
# 2

# %%
total= len(emails)
total
# Out:
# 5

# %%
print("gmail.com:", (gmail/total)*100, "%")
print("yahoo.com:", (yahoo/total)*100, "%")
# Out:
# gmail.com: 60.0 %
# yahoo.com: 40.0 %

# %% [markdown]
# ### Problem Statement 5: Sales Spike Detection

# %%
sales = [1200, 1500, 900, 2200, 1400, 3000]

#Calculate average
average = sum(sales) / len(sales)
average
# Out:
# 1700.0

# %%
# Calculate 30% above average
limit = average * 1.3
limit
# Out:
# 2210.0

# %%
# Detect spike days
for i in range(len(sales)):
    if sales[i] > average:
        print("Day", i+1, ":", sales[i])
# Out:
# Day 4 : 2200
# Day 6 : 3000

# %% [markdown]
# ### Problem Statement 6: Duplicate User ID Detection

# %%
user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]

count = {}

# %%
for user in user_ids:
    if user_ids.count(user) > 1:
        print(user)
# Out:
# user1
# user1
# user3
# user1
# user3

# %%
# Display how many times each duplicate appears.
for user in duplicates:
    print(user, "→", user_ids.count(user), "times")
# Out:
# user1 → 3 times
# user3 → 2 times
